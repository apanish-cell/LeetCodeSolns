# %% [markdown]
# <a href="https://colab.research.google.com/github/apanish-cell/LeetCodeSolns/blob/main/LeetCodeProbs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Two Sum

# %%
class Solution:
  def twoSum(self, nums: list[int], target: int) -> list[int]:
    self.nums = nums
    self.target = target

    for i in range(len(self.nums)):
      for j in range(i+1, len(self.nums)):
        x = self.nums[i]
        if self.nums[j] == self.target - x:
          return [i,j]

# %%
nums = [3,2,4]
target = int(input("Enter a Number: "))

solution_instance = Solution()
result = solution_instance.twoSum(nums, target)
print(result)
# Out:
# Enter a Number: 5
# [0, 1]
